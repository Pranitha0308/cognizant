# %%
name = ["pranitha", "gunny", "hanshu"]
it= iter(name)
print(next(it))
print(next(it))
print(next(it))
# Out:
# pranitha
# gunny
# hanshu

# %%
number = [20, 30, 40]
it=iter(number)
print(next(it))
print(next(it))
print(next(it))
# Out:
# 20
# 30
# 40

# %%
def numbers():
    yield 1
    yield 2
    yield 2
gen = numbers()
print(next(gen))
print(next(gen))
print(next(gen))
# Out:
# 1
# 2
# 2

# %%
file = open("demo.txt", "w")
file.write("Hello Student")
file.close()

# %%
file = open("demo.txt", "r")
content = file.read()
print(content)
file.close()
# Out:
# Hello Student
