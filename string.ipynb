# %%
class Bike:
    color = "black"
    brand = "pulsar"
    speed = 100

bike1 = Bike()
print(bike1.color)
print(bike1.brand)
print(bike1.speed)
# Out:
# black
# pulsar
# 100

# %%
class Student:
    def __init__(self, name, age):
        self.name = name
        self.age = age

s1 = Student("pranitha",19)

print(s1.name)
print(s1.age)
# Out:
# pranitha
# 19
