# %%
name = "pranitha"
print(name)
# Out:
# pranitha

# %%
city = "karimnagar"
print(city[1])
# Out:
# a

# %%
village = "mallial"
print(village)
# Out:
# mallial

# %%
village = "mallial"
print(village[3])
# Out:
# l

# %%
college = "awdc"
print(college[2])
# Out:
# d

# %%
city = "mumbai"
print(city[-3])
# Out:
# b

# %%
object = "mobile"
print(object[-4])
# Out:
# b

# %%
name = "pranitha"
print(name[1:5])
# Out:
# rani

# %%
name = "pranitha"
print(len(name))
# Out:
# 8

# %%
first = "pranitha"
second = "patel"
print(first+ " "+second)
# Out:
# pranitha patel

# %%
print("Hello" * 3)
# Out:
# HelloHelloHello

# %%
print("Hie" * 7)
# Out:
# HieHieHieHieHieHieHie

# %%
print("pranitha" * 100)
# Out:
# ...

# %%
name = "pranitha"
print(name.upper())
# Out:
# PRANITHA

# %%
name = "PRANITHA"
print(name.lower())
# Out:
# pranitha

# %%
s="I like Python"
print(s.replace("Python" , "Java"))
# Out:
# I like Java

# %%
s="anything something"
print(s.find("something"))
# Out:
# 9

# %%
name=input("Enter the name :")
print("welcome", name)
# Out:
# Enter the name : Pranitha
# welcome Pranitha

# %%
p="python"
print(p[::-1])
# Out:
# nohtyp

# %%
j="juice"
print(j[::-2])
# Out:
# eij

# %%
name = "Pranitha"
def greet():
    print("Hello", name)
greet()
# Out:
# Hello Pranitha

# %%
 def add(a,b):
     return a+b
 print(add(10,20))
# Out:
# 30

# %%
def add(a, b, c=0):
    return a+b+c
print(add(10, 20))
print(add(10, 20, 30))
# Out:
# 30
# 60

# %%
def multiply(a,b,c=0):
    return a*b*c
print(multiply(10,20))
print(multiply(10,20,30))
# Out:
# 0
# 6000

# %%
def add(*numbers):
    print(sum(numbers))
add(10,20)
add(10,20,30)
add(10,20,30,40)
# Out:
# 30
# 60
# 100

# %%
def add(*numbers):
    print(sum(numbers))
add(10,20)
add(10,20,30)
add(10,20,30,40)
add(10,20,30,40,50)
# Out:
# 30
# 60
# 100
# 150
