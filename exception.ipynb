# %%
num=10
print(num/0)
print("last line of program")
# Out:
# ---------------------------------------------------------------------------
# ZeroDivisionError                         Traceback (most recent call last)
# Cell In[1], line 2
#       1 num=10
# ----> 2 print(num/0)
#       3 print("last line of program")
#
# ZeroDivisionError: division by zero

# %%
try:
    num=10
    print(num/0)
except ZeroDivisionError:
    print("cannot divide by zero")
# Out:
# cannot divide by zero

# %%
try:
    file=open("xyz.txt","r")
except FileNotFoundError:
    print("File Doesn't Exist")
# Out:
# File Doesn't Exist

# %%
try:
    age=int(input("enter the age"))
except ValueError:
    print("Please Enter The Valid Age")
# Out:
# enter the age 19

# %%
try:
    age=int(input("enter the age"))
except ValueError:
    print("Please Enter The Around Age")
# Out:
# enter the age 19

# %%
try:
    num=int(input("Enter the Number"))
    print(10/num)
except ValueError:
    print("Give The Value Of The Error")
# Out:
# Enter the Number 3103
# 0.003222687721559781
