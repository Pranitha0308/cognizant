# %%
class Parent:
    def func1(self):
        print("This function is in Parent class")
class Child(Parent):
    def func2(self):
        print("This function is in Children class")
object=Child()
object.func1()
object.func2()
# Out:
# This function is in Parent class
# This function is in Children class
